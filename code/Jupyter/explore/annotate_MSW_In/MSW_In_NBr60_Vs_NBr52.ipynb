# %% [markdown]
# The aim of this notebook is to compare NBr54 against 52. In 54 qrun is much smaller for no apparent reason.
#
# For this reason, I'll compare the MSW input files for both runs.
#
# The outcom from the comparrison is recorded in ./MSW_In_NBr54_Vs_NBr52.xlsx

# %% [markdown]
# # 0. Basics

# %% [markdown]
# ## 0.0 Imports

# %%
import pandas as pd
from WS_Mdl.core import *
import xarray as xra
import matplotlib.pyplot as plt

# %% [markdown]
# ## 0.1 Options

# %%
M = Mdl_N('NBr60')
MB = Mdl_N('NBr52')

# %%
Aa = M.Mdl_area - M.N_R*2*M.cellsize - (M.N_C-2)*2*M.cellsize
Aa
# Out:
# 103158900.0

# %% [markdown]
# # 1. Load MSW Ins as DFs

# %%
# DS = M.MSW_In.DS

# %%
# d_DF = {M.MdlN: {}, MB.MdlN: {}}

# %%
# for m in M, MB:    
#     for i, F in enumerate(list(m.Pa.MSW.glob('*.inp'))):
#         print(i+1, end=' ')
#         DF = r_MSW_In.MSW_In_to_DF(F)
#         d_DF[m.MdlN][F.stem.lower()] = DF.rename(columns={'SVAT': 'SVAT'}) if isinstance(DF, pd.DataFrame) else DF # To avoid crashing when MSW_In_to_DF returns None.

# %% [markdown]
# # 2. Explore MSW In files

# %% [markdown]
# Procedure works as follows:
# 1. Check if DFs for Fis are identical (.equals) (Status=3)
# 2. If not, check if they're almost identical (Status=2) or mostly similar (Status=1), or problematic (Status=0)

# %% [markdown]
# ## 2.0 idf_svat
# Starting with this one cause it'll tell help us find the extra SVATs in NBr54, which will be useful for the other

# %% [markdown]
# ### Load & Clean

# %%
Fi = 'idf_svat'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
#  1 - area_svat.inp 🟢
#  2 - fact_svat.inp 🟢
#  3 - idf_svat.inp 🟢
#  4 - infi_svat.inp 🟢
#  5 - init_svat.inp 🟢
#  6 - luse_svat.inp 🟢
#  7 - mete_grid.inp 🟢
#  8 - mod2svat.inp 🟢
#  9 - para_sim.inp 🟢
# 10 - scap_svat.inp 🟡 - Missing 8 columns
# 11 - sel_key_svat_per.inp 🟢
# 12 - svat2etrefgrid.inp 🟢
# 13 - svat2precgrid.inp 🟢
# 14 - svat2swnr_roff.inp 🟢
# 15 - time_sim.inp 🟡 - Missing 2 columns
# 16 - tiop_sim.inp 🟢
#  1 - area_svat.inp 🟢
#  2 - fact_svat.inp 🟢
#  3 - idf_svat.inp 🟢
#  4 - infi_svat.inp 🟢
#  5 - init_svat.inp 🟢
#  6 - luse_svat.inp 🟢
#  7 - mete_grid.inp 🟢
#  8 - mod2svat.inp 🟢
#  9 - para_sim.inp 🟢
# 10 - scap_svat.inp 🟡 - Missing 8 columns
# 11 - sel_key_svat_per.inp 🟢
# 12 - sel_svat_bda.inp 🔴 'sel_svat_bda.inp'
# 13 - svat2etrefgrid.inp 🟢
# 14 - svat2precgrid.inp 🟡 - Missing 2 columns
# 15 - svat2swnr_roff.inp 🟢
# 16 - time_sim.inp 🟡 - Missing 2 columns
# 17 - tiop_sim.inp 🟢
# 18 - uscl_svat.inp 🟡 - Missing 2 columns
# False

# %%
DF.rename(columns={'row number of gridcell (MODFLOW style)': 'R', 'column number of gridcell (MODFLOW style)': 'C'}, inplace=True)
DF_B.rename(columns={'row number of gridcell (MODFLOW style)': 'R', 'column number of gridcell (MODFLOW style)': 'C'}, inplace=True)

# %% [markdown]
# ### Inspect

# %%
DF.describe()
# Out:
#                 SVAT              R              C              X  \
# count  184024.000000  184024.000000  184024.000000  184024.000000
# mean    92012.500000     168.473878     245.539783  119225.994571
# std     53123.297306     100.363154     139.939980    3498.499490
# min         1.000000       2.000000       2.000000  113137.500000
# 25%     46006.750000      78.000000     124.000000  116187.500000
# 50%     92012.500000     169.000000     247.000000  119262.500000
# 75%    138018.250000     257.000000     369.000000  122312.500000
# max    184024.000000     343.000000     479.000000  125062.500000
#
#                   Y
# count  184024.00000
# mean   392000.65304
# std      2509.07884
# min    387637.50000
# 25%    389787.50000
# 50%    391987.50000
# 75%    394262.50000
# max    396162.50000

# %%
DF_B.describe()
# Out:
#                SVAT              R              C              X  \
# count  183388.00000  183388.000000  183388.000000  183388.000000
# mean    91694.50000     168.676287     245.710188  119230.298466
# std     52939.69992     100.378936     139.833887    3495.872738
# min         1.00000       2.000000       2.000000  113137.500000
# 25%     45847.75000      78.000000     124.000000  116187.500000
# 50%     91694.50000     169.000000     247.000000  119262.500000
# 75%    137541.25000     257.000000     369.000000  122312.500000
# max    183388.00000     343.000000     479.000000  125062.500000
#
#                    Y
# count  183388.000000
# mean   391995.593087
# std      2509.473601
# min    387637.500000
# 25%    389787.500000
# 50%    391987.500000
# 75%    394262.500000
# max    396162.500000

# %% [markdown]
# Seems like imod_python creates SVATs in a different way than imod5, as even though we've now removed the outer rows and columns, there are still more SVATs in NBr60 than in NBr52. Let's explore this further.

# %% [markdown]
# ### investigate SVAT Diffs

# %% [markdown]
# There are 165120 (N_R*N_C) cells in the model. There are more SVATs than that though (even though the first and last row and column are inactive in iMOD5). That is because cells with urban_area>0 get 2 SVATs (I checked in QGIS).

# %%
DF['R_C'] = DF['R'].astype(str) + '_' + DF['C'].astype(str)
DF_B['R_C'] = DF_B['R'].astype(str) + '_' + DF_B['C'].astype(str)

# %%
print(f"{len(DF)-len(DF_B)} SVAT grid cells in NBr54 that are not in NBr52 - {(len(DF)-len(DF_B))/len(DF)*100:.2f}%")
# Out:
# 636 SVAT grid cells in NBr54 that are not in NBr52 - 0.35%

# %% [markdown]
# I explore this later

# %%
DF.loc[DF['R_C'].isin(DF_B['R_C']) == False]
# Out:
#           SVAT    R    C         X         Y      R_C
# 105399  105400  222  241  119112.5  390662.5  222_241

# %% [markdown]
# This is the only R_C that's completely missing from B. It is fully wetted (625m2 wetted area), so it might make sense imod5 removed it.

# %% [markdown]
# ### Plot DSs to explore SVAT creation in NBr60 vs NBr52

# %%
DS = M.MSW_In.DS
DS_B = MB.MSW_In.DS
# Out:
#  1 - area_svat 🟢
#  2 - fact_svat 🔴 "None of ['SVAT'] are in the columns"
#  3 - infi_svat 🟢
#  4 - init_svat 🔴 "None of ['SVAT'] are in the columns"
#  5 - luse_svat 🔴 "None of ['SVAT'] are in the columns"
#  6 - mete_grid 🔴 "None of ['SVAT'] are in the columns"
#  7 - mod2svat 🔴 "None of ['SVAT'] are in the columns"
#  8 - para_sim 🔴 "None of ['SVAT'] are in the columns"
#  9 - scap_svat 🟢
# 10 - sel_key_svat_per 🔴 "None of ['SVAT'] are in the columns"
# 11 - svat2etrefgrid 🟢
# 12 - svat2precgrid 🟢
# 13 - svat2swnr_roff 🟢
# 14 - time_sim 🔴 "None of ['SVAT'] are in the columns"
# 15 - tiop_sim 🔴 "None of ['SVAT'] are in the columns"
#  1 - area_svat 🟢
#  2 - fact_svat 🔴 "None of ['SVAT'] are in the columns"
#  3 - infi_svat 🟢
#  4 - init_svat 🔴 "None of ['SVAT'] are in the columns"
#  5 - luse_svat 🔴 "None of ['SVAT'] are in the columns"
#  6 - mete_grid 🔴 "None of ['SVAT'] are in the columns"
#  7 - mod2svat 🔴 "None of ['SVAT'] are in the columns"
#  8 - para_sim 🔴 "None of ['SVAT'] are in the columns"
#  9 - scap_svat 🟢
# 10 - sel_key_svat_per 🔴 "None of ['SVAT'] are in the columns"
# 11 - sel_svat_bda 🔴 'NoneType' object has no attribute 'set_index'
# 12 - svat2etrefgrid 🟢
# 13 - svat2precgrid 🟢
# 14 - svat2swnr_roff 🟢
# 15 - time_sim 🔴 "None of ['SVAT'] are in the columns"
# 16 - tiop_sim 🔴 "None of ['SVAT'] are in the columns"
# 17 - uscl_svat 🟢

# %%
DS['SVAT'].sel(N=0).notnull().plot(yincrease=False)

# %%
DS['SVAT'].sel(N=1).notnull().plot(yincrease=False)

# %%
extra = DS['SVAT'].sel(N=1).notnull() & DS_B['SVAT'].sel(N=1).isnull() # Extra SVATs in NBr60 that are not in NBr52
extra.plot(yincrease=False)

# %% [markdown]
# #### Explore smaller area, to understand what's happening

# %%
extra = DS['SVAT'].sel(N=1).notnull() & DS_B['SVAT'].sel(N=1).isnull() # Extra SVATs in NBr60 that are not in NBr52
(extra.sel(R=slice(235, 250), C=slice(235, 250))).plot(yincrease=False)

# %%
DS['SVAT'].sel(N=1).notnull().sel(R=slice(235, 250), C=slice(235, 250)).plot(yincrease=False)

# %%
DS_B['SVAT'].sel(N=1).notnull().sel(R=slice(235, 250), C=slice(235, 250)).plot(yincrease=False)

# %% [markdown]
# - imod_python (NBr60) creates a 2nd SVAT for the same cell when urban area > 0.
# - imod5 (NBr52) creates a 2nd SVAT when urban area > 0 and wetted area <= 20% (not sure about the exact percentage, but I see cells with 75 (or 86.1192) m2 wetted area getting a 2nd SVAT, while cells with 125m2 don't (in both cases urban area > 0)). (total cell area is 625m2)

# %% [markdown]
# ## 2.1 area_svat

# %% [markdown]
# ### Compare DFs

# %%
Fi = 'area_svat'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# False

# %%
DF.describe()
# Out:
#                 SVAT           area  temperature at bottom of soil profile  \
# count  184024.000000  184024.000000                          184024.000000
# mean    92012.500000     555.089051                              12.867458
# std     53123.297306     196.266114                               5.253305
# min         1.000000       0.384169                               1.083940
# 25%     46006.750000     624.237760                               8.853417
# 50%     92012.500000     625.000000                              12.353600
# 75%    138018.250000     625.000000                              16.640400
# max    184024.000000     625.000000                              29.856300
#
#        soil physical unit number / or / soil physical unit descriptive string  \
# count                                      184024.000000
# mean                                          105.784756
# std                                            34.970745
# min                                            36.000000
# 25%                                            79.000000
# 50%                                            84.000000
# 75%                                           130.000000
# max                                           360.000000
#
#        land use type  root zone thickness / maximum
# count  184024.000000                  184024.000000
# mean        8.750413                       0.517066
# std         7.183651                       0.299450
# min         1.000000                       0.050000
# 25%         1.000000                       0.300000
# 50%        11.000000                       0.350000
# 75%        17.000000                       1.000000
# max        22.000000                       1.000000

# %%
DF_B.describe()
# Out:
#                SVAT           area  temperature at bottom of soil profile  \
# count  183388.00000  183388.000000                          183388.000000
# mean    91694.50000     536.798038                              12.879104
# std     52939.69992     150.606197                               5.252083
# min         1.00000       1.110000                               1.084000
# 25%     45847.75000     500.000000                               8.867000
# 50%     91694.50000     625.000000                              12.360500
# 75%    137541.25000     625.000000                              16.655000
# max    183388.00000     625.000000                              29.856000
#
#        soil physical unit number / or / soil physical unit descriptive string  \
# count                                      183388.000000
# mean                                          105.777096
# std                                            34.991614
# min                                            36.000000
# 25%                                            79.000000
# 50%                                            84.000000
# 75%                                           130.000000
# max                                           360.000000
#
#        land use type  root zone thickness / maximum  \
# count  183388.000000                  183388.000000
# mean        8.718346                       0.481972
# std         7.175392                       0.317850
# min         1.000000                       0.100000
# 25%         1.000000                       0.300000
# 50%        11.000000                       0.350000
# 75%        17.000000                       0.750000
# max        22.000000                       1.000000
#
#        meteorological region code number  \
# count                           183388.0
# mean                                 1.0
# std                                  0.0
# min                                  1.0
# 25%                                  1.0
# 50%                                  1.0
# 75%                                  1.0
# max                                  1.0
#
#        local calibration factor for precipitation  \
# count                                    183388.0
# mean                                          1.0
# std                                           0.0
# min                                           1.0
# 25%                                           1.0
# 50%                                           1.0
# 75%                                           1.0
# max                                           1.0
#
#        local calibration factor for potential evapotranspiration of reference crop
# count                                           183388.0
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0

# %%
f"{(DF['area'].sum() - DF_B['area'].sum() ) / DF_B['area'].sum() *100:.2f}%"
# Out:
# '3.77%'

# %% [markdown]
# We have 3.8% difference in precipitation between runs - it's rounded to the same decimal, so it's probably exactly the same as the area difference.
#
# Let's attach this Fieter to the DS and explore spatially.

# %% [markdown]
# ### Compare DS Fis

# %% [markdown]
# #### area

# %% [markdown]
# Let's compare the area per R and C.

# %%
param = 'area'

# %%
area_RC = DS[param].sum(dim='N', skipna=True)
area_RC_B = DS_B[param].sum(dim='N', skipna=True)
area_RC_Diff = area_RC - area_RC_B

# %%
area_RC_Diff.plot(yincrease=False)

# %%
area_RC.sel(R=slice(220, 235), C=slice(235, 250)).plot(yincrease=False, cmap='Spectral')

# %%
area_RC.sel(R=slice(220, 235), C=slice(235, 250)).min()
# Out:
# <xarray.DataArray 'area' ()> Size: 8B
# array(621.18879)

# %%
area_RC_B.sel(R=slice(220, 235), C=slice(235, 250)).plot(yincrease=False, cmap='Spectral')

# %%
area_RC_Diff.sel(R=slice(220, 235), C=slice(235, 250)).plot(yincrease=False, cmap='Spectral')

# %% [markdown]
# It's clear that imod5 removes wetted area from the total cell area. It's not as clear what imod_python does, but there is a big difference in wetted cell areas.

# %%
DF.keys()
# Out:
# Index(['SVAT', 'area', 'temperature at bottom of soil profile',
#        'soil physical unit number / or / soil physical unit descriptive string',
#        'land use type', 'root zone thickness / maximum'],
#       dtype='object')

# %% [markdown]
# #### temperature at bottom of soil profile

# %%
param = DF_B.columns[2]
param
# Out:
# 'temperature at bottom of soil profile'

# %%
area_RC = DS[param].sum(dim='N', skipna=True)
area_RC_B = DS_B[param].sum(dim='N', skipna=True)
area_RC_Diff = area_RC - area_RC_B

# %%
area_RC_Diff.plot(yincrease=False)

# %% [markdown]
# This is the same pattern as extra SVATs.

# %%
area_RC_Diff.sel(R=slice(220, 235), C=slice(235, 250)).plot(yincrease=False, cmap='Spectral')

# %% [markdown]
# #### Other parameters

# %%
d_missing = {M.MdlN: [], MB.MdlN: []}
for i in range(len(DF_B.columns)-3):
    param = DF_B.columns[3+i]
    print(param)
    if param in DS.data_vars and param in DS_B.data_vars:
        area_RC = DS[param].sum(dim='N', skipna=True)
        area_RC_B = DS_B[param].sum(dim='N', skipna=True)
        area_RC_Diff = area_RC - area_RC_B
        area_RC_Diff.plot(yincrease=False)
        plt.show()
    elif param in DS.data_vars and param not in DS_B.data_vars:
        d_missing[M.MdlN].append(param)
    elif param not in DS.data_vars and param in DS_B.data_vars:
        d_missing[MB.MdlN].append(param)
# Out:
# soil physical unit number / or / soil physical unit descriptive string
# land use type
# root zone thickness / maximum
# meteorological region code number
# local calibration factor for precipitation
# local calibration factor for potential evapotranspiration of reference crop

# %% [markdown]
# Other parameters

# %% [markdown]
# ## 2.2 fact_svat

# %%
Fi = 'fact_svat'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# True

# %% [markdown]
# Since DFs are identical, no further investigation is needed.

# %% [markdown]
# ## 2.4 infi_svat

# %%
Fi = 'infi_svat'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# False

# %%
DF.describe()
# Out:
#                 SVAT  infiltration capacity of soil surface  \
# count  184024.000000                          184024.000000
# mean    92012.500000                               0.932758
# std     53123.297306                               0.330695
# min         1.000000                               0.000000
# 25%     46006.750000                               1.050000
# 50%     92012.500000                               1.050000
# 75%    138018.250000                               1.050000
# max    184024.000000                               1.050000
#
#        downward flow resistance of soil surface  \
# count                                  184024.0
# mean                                     9999.0
# std                                         0.0
# min                                      9999.0
# 25%                                      9999.0
# 50%                                      9999.0
# 75%                                      9999.0
# max                                      9999.0
#
#        upward flow resistance of soil surface  \
# count                                184024.0
# mean                                   9999.0
# std                                       0.0
# min                                    9999.0
# 25%                                    9999.0
# 50%                                    9999.0
# 75%                                    9999.0
# max                                    9999.0
#
#        flow resistance of bottom flux link (c-link)  \
# count                                      184024.0
# mean                                         9999.0
# std                                             0.0
# min                                          9999.0
# 25%                                          9999.0
# 50%                                          9999.0
# 75%                                          9999.0
# max                                          9999.0
#
#        extra storage coefficient of phreatic layer
# count                                     184024.0
# mean                                           1.0
# std                                            0.0
# min                                            1.0
# 25%                                            1.0
# 50%                                            1.0
# 75%                                            1.0
# max                                            1.0

# %%
DF_B.describe()
# Out:
#                SVAT  infiltration capacity of soil surface  \
# count  183388.00000                          183388.000000
# mean    91694.50000                               0.932351
# std     52939.69992                               0.331196
# min         1.00000                               0.000000
# 25%     45847.75000                               1.050000
# 50%     91694.50000                               1.050000
# 75%    137541.25000                               1.050000
# max    183388.00000                               1.050000
#
#        downward flow resistance of soil surface  \
# count                                  183388.0
# mean                                    -9999.0
# std                                         0.0
# min                                     -9999.0
# 25%                                     -9999.0
# 50%                                     -9999.0
# 75%                                     -9999.0
# max                                     -9999.0
#
#        upward flow resistance of soil surface  \
# count                                183388.0
# mean                                  -9999.0
# std                                       0.0
# min                                   -9999.0
# 25%                                   -9999.0
# 50%                                   -9999.0
# 75%                                   -9999.0
# max                                   -9999.0
#
#        flow resistance of bottom flux link (c-link)  \
# count                                      183388.0
# mean                                        -9999.0
# std                                             0.0
# min                                         -9999.0
# 25%                                         -9999.0
# 50%                                         -9999.0
# 75%                                         -9999.0
# max                                         -9999.0
#
#        extra storage coefficient of phreatic layer
# count                                     183388.0
# mean                                       -9999.0
# std                                            0.0
# min                                        -9999.0
# 25%                                        -9999.0
# 50%                                        -9999.0
# 75%                                        -9999.0
# max                                        -9999.0

# %% [markdown]
# #### infiltration capacity of soil surface

# %%
param = 'infiltration capacity of soil surface'
param
# Out:
# 'infiltration capacity of soil surface'

# %%
area_RC = DS[param].sum(dim='N', skipna=True)
area_RC_B = DS_B[param].sum(dim='N', skipna=True)
area_RC_Diff = area_RC - area_RC_B

# %%
area_RC_Diff.plot(yincrease=False)

# %% [markdown]
# This is the same pattern as extra SVATs. The rest of the params are practically NaNs, except "extra storage coefficient of phreatic layer", which also doesn't make a difference (I've tested it).

# %% [markdown]
# ## 2.5 init_svat

# %%
Fi = 'init_svat'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# True

# %% [markdown]
# ## 2.6 luse_svat

# %%
Fi = 'luse_svat'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# True

# %% [markdown]
# ## 2.7 mete_grid

# %%
Fi = 'mete_grid'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# False

# %%
DF.describe(include='all')
# Out:
#         time from 00:00:00  year number  \
# count          4383.000000  4383.000000
# unique                 NaN          NaN
# top                    NaN          NaN
# freq                   NaN          NaN
# mean            182.125257  1998.501027
# std             105.450673     3.452545
# min               0.000000  1993.000000
# 25%              91.000000  1996.000000
# 50%             182.000000  1999.000000
# 75%             273.000000  2001.500000
# max             365.000000  2004.000000
#
#                            path\name precipitation grid  \
# count                                              4383
# unique                                             4383
# top     G:\models\NBr\In\CAP\P\NBr1\P_19930101_NBr1.asc
# freq                                                  1
# mean                                                NaN
# std                                                 NaN
# min                                                 NaN
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                                 NaN
#
#        path\name evapotranspiration grid(reference crop values)  \
# count                                                4383
# unique                                               4383
# top     G:\models\NBr\In\CAP\PET\NBr1\PET_19930101_NBr...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        path\name min. day temperature grid  \
# count                                 4383
# unique                                   1
# top                                NoValue
# freq                                  4383
# mean                                   NaN
# std                                    NaN
# min                                    NaN
# 25%                                    NaN
# 50%                                    NaN
# 75%                                    NaN
# max                                    NaN
#
#        path\name max. day temperature grid path\name mean temperature grid  \
# count                                 4383                            4383
# unique                                   1                               1
# top                                NoValue                         NoValue
# freq                                  4383                            4383
# mean                                   NaN                             NaN
# std                                    NaN                             NaN
# min                                    NaN                             NaN
# 25%                                    NaN                             NaN
# 50%                                    NaN                             NaN
# 75%                                    NaN                             NaN
# max                                    NaN                             NaN
#
#        path\name relative sunshine duration grid path\name radiation grid  \
# count                                       4383                     4383
# unique                                         1                        1
# top                                      NoValue                  NoValue
# freq                                        4383                     4383
# mean                                         NaN                      NaN
# std                                          NaN                      NaN
# min                                          NaN                      NaN
# 25%                                          NaN                      NaN
# 50%                                          NaN                      NaN
# 75%                                          NaN                      NaN
# max                                          NaN                      NaN
#
#        path\name humidity grid path\name wind speed grid
# count                     4383                      4383
# unique                       1                         1
# top                    NoValue                   NoValue
# freq                      4383                      4383
# mean                       NaN                       NaN
# std                        NaN                       NaN
# min                        NaN                       NaN
# 25%                        NaN                       NaN
# 50%                        NaN                       NaN
# 75%                        NaN                       NaN
# max                        NaN                       NaN

# %%
DF_B.describe(include='all')
# Out:
#         time from 00:00:00  year number  \
# count          4383.000000  4383.000000
# unique                 NaN          NaN
# top                    NaN          NaN
# freq                   NaN          NaN
# mean            182.125257  1998.501027
# std             105.450673     3.452545
# min               0.000000  1993.000000
# 25%              91.000000  1996.000000
# 50%             182.000000  1999.000000
# 75%             273.000000  2001.500000
# max             365.000000  2004.000000
#
#                            path\name precipitation grid  \
# count                                              4383
# unique                                             4383
# top     G:\models\NBr\In\CAP\P\NBr1\P_19930101_NBr1.asc
# freq                                                  1
# mean                                                NaN
# std                                                 NaN
# min                                                 NaN
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                                 NaN
#
#        path\name evapotranspiration grid(reference crop values)  \
# count                                                4383
# unique                                               4383
# top     G:\models\NBr\In\CAP\PET\NBr1\PET_19930101_NBr...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        path\name min. day temperature grid  \
# count                                 4383
# unique                                   1
# top                                NoValue
# freq                                  4383
# mean                                   NaN
# std                                    NaN
# min                                    NaN
# 25%                                    NaN
# 50%                                    NaN
# 75%                                    NaN
# max                                    NaN
#
#        path\name max. day temperature grid path\name mean temperature grid  \
# count                                 4383                            4383
# unique                                   1                               1
# top                                NoValue                         NoValue
# freq                                  4383                            4383
# mean                                   NaN                             NaN
# std                                    NaN                             NaN
# min                                    NaN                             NaN
# 25%                                    NaN                             NaN
# 50%                                    NaN                             NaN
# 75%                                    NaN                             NaN
# max                                    NaN                             NaN
#
#        path\name relative sunshine duration grid path\name radiation grid  \
# count                                       4383                     4383
# unique                                         1                        1
# top                                      NoValue                  NoValue
# freq                                        4383                     4383
# mean                                         NaN                      NaN
# std                                          NaN                      NaN
# min                                          NaN                      NaN
# 25%                                          NaN                      NaN
# 50%                                          NaN                      NaN
# 75%                                          NaN                      NaN
# max                                          NaN                      NaN
#
#        path\name humidity grid path\name wind speed grid
# count                     4383                      4383
# unique                       1                         1
# top                    NoValue                   NoValue
# freq                      4383                      4383
# mean                       NaN                       NaN
# std                        NaN                       NaN
# min                        NaN                       NaN
# 25%                        NaN                       NaN
# 50%                        NaN                       NaN
# 75%                        NaN                       NaN
# max                        NaN                       NaN

# %%
diff_cols = DF.columns[~DF.eq(DF_B).all()]
diff_cols
# Out:
# Index(['path\name precipitation grid', 'path\name evapotranspiration grid(reference crop values)'], dtype='object')

# %% [markdown]
# CAPS diffs in path cols. Those definitely don't matter, otherwise I'd be missing all of P/EVT in one Sim.

# %% [markdown]
# ## 2.8 mod2svat

# %%
Fi = 'mod2svat'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# False

# %%
diff_cols = DF.columns[~DF.eq(DF_B).all()]
diff_cols
# Out:
# Index(['Modflow-id', 'index of SVAT-unit', 'layer of SVAT-unit'], dtype='object')

# %%
DF
# Out:
#         Modflow-id  index of SVAT-unit  layer of SVAT-unit
# 0          1299310                   1                  13
# 1          1299311                   2                  13
# 2          1299312                   3                  13
# 3          1752082                 117                  17
# 4          1752083                 118                  17
# ...            ...                 ...                 ...
# 211462      164635              184020                   1
# 211463      164636              184021                   1
# 211464      164637              184022                   1
# 211465      164638              184023                   1
# 211466      164639              184024                   1
#
# [211467 rows x 3 columns]

# %%
DF.describe(include='all')
# Out:
#          Modflow-id  index of SVAT-unit  layer of SVAT-unit
# count  2.114670e+05       211467.000000       211467.000000
# mean   2.840734e+05        91266.550871            2.894149
# std    5.344250e+05        53119.757743            4.950680
# min    4.820000e+02            1.000000            1.000000
# 25%    4.323250e+04        45523.500000            1.000000
# 50%    9.399400e+04        90998.000000            1.000000
# 75%    1.405655e+05       138014.500000            1.000000
# max    2.174030e+06       184024.000000           19.000000

# %%
DF_B.describe(include='all')
# Out:
#          Modflow-id  index of SVAT-unit  layer of SVAT-unit
# count  2.091740e+05       209174.000000       209174.000000
# mean   2.743038e+05        91809.175270            2.799927
# std    5.237708e+05        53199.856967            4.845565
# min    4.820000e+02            1.000000            1.000000
# 25%    4.299725e+04        46011.250000            1.000000
# 50%    9.344250e+04        91876.500000            1.000000
# 75%    1.395698e+05       137687.000000            1.000000
# max    2.172913e+06       183388.000000           19.000000

# %% [markdown]
# ## 2.9 para_sim

# %%
Fi = 'para_sim'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# False

# %% [markdown]
# Comments left in .xlsx
#
# Non Array-like, so there is no further exploration.

# %% [markdown]
# ## 2.10 scap_svat

# %%
Fi = 'scap_svat'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# False

# %%
diff_cols = DF.columns[~DF.eq(DF_B).all()]
diff_cols
# Out:
# Index(['SVAT', 'maximum abstraction from groundwater mm/d',
#        'maximum abstraction from surface water mm/d',
#        'maximum abstraction from groundwater m3/d',
#        'fraction of abstraction from surface water m3/d'],
#       dtype='object')

# %%
DF.describe(include='all')
# Out:
#                 SVAT  maximum abstraction from groundwater mm/d  \
# count   25812.000000                                        0.0
# mean    80837.406439                                        NaN
# std     49697.040372                                        NaN
# min         1.000000                                        NaN
# 25%     38281.750000                                        NaN
# 50%     81736.500000                                        NaN
# 75%    125832.250000                                        NaN
# max    163471.000000                                        NaN
#
#        maximum abstraction from surface water mm/d  \
# count                                          0.0
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        maximum abstraction from groundwater m3/d  \
# count                               25812.000000
# mean                                   15.621422
# std                                     0.008541
# min                                    15.518300
# 25%                                    15.625000
# 50%                                    15.625000
# 75%                                    15.625000
# max                                    15.625000
#
#        fraction of abstraction from surface water m3/d
# count                                          25812.0
# mean                                               0.0
# std                                                0.0
# min                                                0.0
# 25%                                                0.0
# 50%                                                0.0
# 75%                                                0.0
# max                                                0.0

# %%
DF_B.describe(include='all')
# Out:
#                 SVAT  maximum abstraction from groundwater mm/d  \
# count   25786.000000                                    25786.0
# mean    92624.736756                                       25.0
# std     55008.758796                                        0.0
# min         1.000000                                       25.0
# 25%     47826.250000                                       25.0
# 50%     93258.500000                                       25.0
# 75%    141819.750000                                       25.0
# max    183378.000000                                       25.0
#
#        maximum abstraction from surface water mm/d  \
# count                                          0.0
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        maximum abstraction from groundwater m3/d  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        fraction of abstraction from surface water m3/d
# count                                              0.0
# mean                                               NaN
# std                                                NaN
# min                                                NaN
# 25%                                                NaN
# 50%                                                NaN
# 75%                                                NaN
# max                                                NaN

# %% [markdown]
# ## 2.11 sel_key_svat_per

# %%
Fi = 'sel_key_svat_per'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# True

# %% [markdown]
# ## 2.13 svat2etrefgrid

# %%
Fi = 'svat2etrefgrid'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# False

# %%
DF.describe()
# Out:
#                 SVAT  row number of ETREF grid  column number of ETREF grid
# count  184024.000000             184024.000000                184024.000000
# mean    92012.500000                233.503760                   119.721254
# std     53123.297306                  2.530364                     3.498742
# min         1.000000                229.000000                   114.000000
# 25%     46006.750000                231.000000                   117.000000
# 50%     92012.500000                234.000000                   120.000000
# 75%    138018.250000                236.000000                   123.000000
# max    184024.000000                238.000000                   126.000000

# %%
DF_B.describe(include='all')
# Out:
#                SVAT  row number of ETREF grid  column number of ETREF grid
# count  183388.00000             183388.000000                183388.000000
# mean    91694.50000                233.508937                   119.725816
# std     52939.69992                  2.530613                     3.495910
# min         1.00000                229.000000                   114.000000
# 25%     45847.75000                231.000000                   117.000000
# 50%     91694.50000                234.000000                   120.000000
# 75%    137541.25000                236.000000                   123.000000
# max    183388.00000                238.000000                   126.000000

# %% [markdown]
# ## 2.14 svat2precgrid

# %%
Fi = 'svat2precgrid'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# False

# %%
DF.describe()
# Out:
#                 SVAT  row number of PREC grid  column number of PREC grid
# count  184024.000000            184024.000000               184024.000000
# mean    92012.500000               233.503760                  119.721254
# std     53123.297306                 2.530364                    3.498742
# min         1.000000               229.000000                  114.000000
# 25%     46006.750000               231.000000                  117.000000
# 50%     92012.500000               234.000000                  120.000000
# 75%    138018.250000               236.000000                  123.000000
# max    184024.000000               238.000000                  126.000000

# %%
DF_B.describe(include='all')
# Out:
#                SVAT  row number of PREC grid  column number of PREC grid
# count  183388.00000            183388.000000               183388.000000
# mean    91694.50000               233.508937                  119.725816
# std     52939.69992                 2.530613                    3.495910
# min         1.00000               229.000000                  114.000000
# 25%     45847.75000               231.000000                  117.000000
# 50%     91694.50000               234.000000                  120.000000
# 75%    137541.25000               236.000000                  123.000000
# max    183388.00000               238.000000                  126.000000

# %% [markdown]
# ## 2.15 svat2swnr_roff

# %%
Fi = 'svat2swnr_roff'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# False

# %%
DF.describe()
# Out:
#                 SVAT  surface water location identifier  \
# count  184024.000000                           184024.0
# mean    92012.500000                                0.0
# std     53123.297306                                0.0
# min         1.000000                                0.0
# 25%     46006.750000                                0.0
# 50%     92012.500000                                0.0
# 75%    138018.250000                                0.0
# max    184024.000000                                0.0
#
#        micro-storage capacity, =sill of the runoff relationship  \
# count                                       1.840240e+05
# mean                                        2.000000e-03
# std                                         5.593197e-15
# min                                         2.000000e-03
# 25%                                         2.000000e-03
# 50%                                         2.000000e-03
# 75%                                         2.000000e-03
# max                                         2.000000e-03
#
#        runoff resistance  runon resistance
# count           184024.0          184024.0
# mean                 1.0               1.0
# std                  0.0               0.0
# min                  1.0               1.0
# 25%                  1.0               1.0
# 50%                  1.0               1.0
# 75%                  1.0               1.0
# max                  1.0               1.0

# %%
DF_B.describe(include='all')
# Out:
#                SVAT  surface water location identifier  \
# count  183388.00000                           183388.0
# mean    91694.50000                                0.0
# std     52939.69992                                0.0
# min         1.00000                                0.0
# 25%     45847.75000                                0.0
# 50%     91694.50000                                0.0
# 75%    137541.25000                                0.0
# max    183388.00000                                0.0
#
#        micro-storage capacity, =sill of the runoff relationship  \
# count                                       1.833880e+05
# mean                                        2.000000e-03
# std                                         5.579320e-15
# min                                         2.000000e-03
# 25%                                         2.000000e-03
# 50%                                         2.000000e-03
# 75%                                         2.000000e-03
# max                                         2.000000e-03
#
#        runoff resistance  runon resistance
# count           183388.0          183388.0
# mean                 1.0               1.0
# std                  0.0               0.0
# min                  1.0               1.0
# 25%                  1.0               1.0
# 50%                  1.0               1.0
# 75%                  1.0               1.0
# max                  1.0               1.0

# %% [markdown]
# ## 2.17 tiop_sim

# %%
Fi = 'tiop_sim'
DF, DF_B = M.MSW_In.d[Fi].copy(), MB.MSW_In.d[Fi].copy()
DF.equals(DF_B)
# Out:
# False

# %%
DF.describe()
# Out:
#        time from beginning of year at 00:00:00  year number  option number
# count                                93.000000         93.0           93.0
# mean                                 46.000000       1996.0            7.0
# std                                  26.990739          0.0            0.0
# min                                   0.000000       1996.0            7.0
# 25%                                  23.000000       1996.0            7.0
# 50%                                  46.000000       1996.0            7.0
# 75%                                  69.000000       1996.0            7.0
# max                                  92.000000       1996.0            7.0

# %%
DF_B.describe(include='all')
# Out:
#        time from beginning of year at 00:00:00   year number  option number
# count                             10227.000000  10227.000000        10227.0
# mean                                182.125257   2006.501027            7.0
# std                                 105.443798      8.078184            0.0
# min                                   0.000000   1993.000000            7.0
# 25%                                  91.000000   2000.000000            7.0
# 50%                                 182.000000   2007.000000            7.0
# 75%                                 273.000000   2013.500000            7.0
# max                                 365.000000   2020.000000            7.0

# %% [markdown]
# ## 2.18 uscl_svat

# %% [markdown]
# Missing in NBr54

# %% [markdown]
# # -1 Junkyard

# %%
for k in MB.MSW_In.d.keys():
    try:
        print('\n'.join(MB.MSW_In.d[k].columns))
        print('---------------------')
    except:
        continue
